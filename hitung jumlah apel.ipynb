# %%
from matplotlib import pyplot as plt
import cv2

sawit = cv2.imread('apel crop.jpg')
sawit = cv2.cvtColor(sawit, cv2.COLOR_BGR2RGB)


kebun_sawit = cv2.imread('apel.jpg')
kebun_sawit = cv2.cvtColor(kebun_sawit, cv2.COLOR_BGR2RGB)

plt.subplot(121),plt.imshow(sawit), plt.title('apel')
plt.subplot(122),plt.imshow(kebun_sawit), plt.title('kumpulan apel')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img_rgb = cv2.imread('apel.jpg')
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)


template = cv2.imread('apel crop.jpg',0)


w, h = template.shape[::-1]

res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)

threshold = 0.15
loc = np.where(res >= threshold)

lspoint=[]
lspoint2=[]
count = 0
for pt in zip(*loc[::-1]):
    if pt[0] not in lspoint and pt[1] not in lspoint2:
        
        cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)
        for i in range(((pt[0])-9), ((pt[0])+9),1):
            
            lspoint.append(i)
        for k in range(((pt[1])-9), ((pt[1])+9),1):
            
            lspoint2.append(k)
        count+=1
    else:
        continue
print ("Jumlah objek ditemukan ", count)

plt.imshow(cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Jumlah objek ditemukan  55
